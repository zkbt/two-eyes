# %%
from twoeyes import MakeYourOwn

# %%
s = MakeYourOwn()
# Out:
# GridspecLayout(children=(FileUpload(value={}, description='left', layout=Layout(grid_area='widget001', height=…
# wrote to left.jpg
# wrote to right.jpg

# %%
# !open .

# %%
i = Image.open('../left.jpg')

# %%
display(i)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x1024 at 0x7FF53FA52100>
