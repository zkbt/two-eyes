# %% [markdown]
# # Make Your Own Stereographs
#
# Many humans can sense the 3D distance to objects because we see them from two eyes at slightly different locations, and closer objects appear to move relative to distant ones. In astronomy, we use stereo viewing to make [3D images of other planets](https://mars.nasa.gov/3d/images/) and [measure distances to nearby stars via stellar parallax](https://www.nasa.gov/feature/nasa-s-new-horizons-conducts-the-first-interstellar-parallax-experiment).
#
# **This interactive notebook** allows you to upload images representing the same scene viewed from two slightly different perspectives and stitch them together into one stereographic image.
# + You will get a warning that this notebook was not authored by google. It was authored by Zach Berta-Thompson who is not trying to do anything sneaky. For those who are curious, the complete source code is [available on github](https://github.com/zkbt/two-eyes).
# + You can upload any normal image file (jpg, png, tif, gif). Large files may take some time to upload and display, so please be patient or upload smaller image files.
# + You can check the "phone" option for a more mobile-friendly interface.

# %%
#@title Please type your name, then press (|>) on the left.
from ipywidgets import Output
from IPython.display import display, clear_output
hidden_output = Output()

# ask for the user's name
name = 'Zach' #@param {type:"string"}
phone = False #@param {type:"boolean"}

# make a tidy version of the name good for saving files
tidy_name = name.lower().replace('''!@#$%^&*(){}[]|\:";'<>,./?''', '').replace(' ', '-')
prefix = f'stereograph-by-{tidy_name}'

with hidden_output:
  if name != '':
    print(f'Hello, {name}!')

display(hidden_output)

with hidden_output:
  print("Please wait while we install some code.")
  # !pip install -q two-eyes --upgrade
  print("All done!")
  clear_output()
print()
from twoeyes import MakeYourOwn; s = MakeYourOwn(prefix=prefix, phone=phone, colab=True)
# Out:
# <>:15: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:15: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-1-6ab1d83b20cc>:15: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if name is not '':
# Output()
# ...

# %% [markdown]
# Once your stereographic images have been created, click the small folder icon in the menu on the left and find your file(s). You can double click to view them in the browser or click the "..." to download.
